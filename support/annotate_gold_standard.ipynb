# %% [markdown]
# # Annotation tool

# %% [markdown]
# This tool is used to annotate links. The tool is configured to annotate fb15k and dbpedia.

# %% [markdown]
# First, specify the paths of the test files

# %%
import pickle as pkl
import numpy
import copy
import torch
import json
import ipywidgets as widgets
from ipywidgets import interact, Layout, ButtonStyle
from IPython.display import Markdown
import requests
from time import sleep
import random
import datetime
import os
import urllib
from functools import cmp_to_key

# %%
db_name = 'dbpedia50'
main_folder = '/var/scratch2/uji300/OpenKE-results/' + db_name + '/'
annotations_file = main_folder + "annotations/gold-annotations.json"
testdata_raw_path = '../benchmarks/' + db_name + '/test2id.txt'
annotator = 'U'
mode = 0 # If the mode is 0, then we always try to select new queries first. If it's 1, we will select queries already annotated

# %%
testdata_folder = main_folder + 'answers/'
testdata_transe_path_head = testdata_folder + db_name + '-answers-transe-test-10-head.pkl'
testdata_transe_path_tail = testdata_folder + db_name + '-answers-transe-test-10-tail.pkl'
# testdata_complex_path_head = testdata_folder + db_name + '-answers-complex-test-10-head.pkl'
# testdata_complex_path_tail = testdata_folder + db_name + '-answers-complex-test-10-tail.pkl'
# testdata_rotate_path_head = testdata_folder + db_name + '-answers-rotate-test-10-head.pkl'
# testdata_rotate_path_tail = testdata_folder + db_name + '-answers-rotate-test-10-tail.pkl'

# %% [markdown]
# Load the dictionary

# %%
ent_labels_path = '../benchmarks/%s/entity2id.txt' % db_name
rel_labels_path = '../benchmarks/%s/relation2id.txt' % db_name

# %%
ent_labels = {}
with open(ent_labels_path, 'rt') as f:
    nents = int(f.readline())
    for line in f:
        tkns = line.split('\t')
        ent_labels[int(tkns[1])] = tkns[0]
    assert(len(ent_labels) == nents)
rel_labels = {}
with open(rel_labels_path, 'rt') as f:
    nrels = int(f.readline())
    for line in f:
        tkns = line.split('\t')
        rel_labels[int(tkns[1])] = tkns[0]
    assert(len(rel_labels) == nrels)

# %%
ent_labels
# Out:
# {0: 'Bruno_Bianchi_(cartoonist)',
#  1: 'The_Final_Frontier',
#  2: 'Nurse_Edith_Cavell',
#  3: 'Pablo_Gaglianone',
#  4: 'The_Heights_(TV_series)',
#  5: 'Dominique_Bathenay',
#  6: 'Arsinée_Khanjian',
#  7: 'Kelly_(Kelly_Price_album)',
#  8: 'Kyaw_Hsan',
#  9: 'Bopyridae',
#  10: 'Rheinfelden_District',
#  11: 'The_Lion_Sleeps_Tonight',
#  12: 'Villar_del_Arzobispo',
#  13: 'Hydrophylloideae',
#  14: 'CD_Corralejo',
#  15: 'S.E.S._(band)',
#  16: 'Dave_McClements',
#  17: 'Firuzabad,_Fars',
#  18: 'Norbert_Putnam',
#  19: 'Rubik,_the_Amazing_Cube',
#  20: 'Gigle_Networks',
#  21: 'Parker_Lundgren',
#  22: 'Toto_XIV',
#  23: 'Jim_Landtroop',
#  24: 'Ioan_Sabău',
#  25: 'Brittonic_languages',
#  26: 'T.H.E._(The_Hardest_Ever)',
#  27: 'The_Proud_Family_Movie',
#  28: 'Rudimental',
#  29: 'Robert_Mapplethorpe',
#  30: 'Balloons_(song)',
#  31: 'WREC',
#  32: 'David_Starčević',
#  33: 'My_Little_Secret',
#  34: 'Rob_Atkinson_(surgeon)',
#  35: 'Corrado_Tommasi-Crudeli',
#  36: 'Surianaceae',
#  37: 'Association_of_Independent_Technological_Universities',
#  38: 'Dusty_Springfield',
#  39: 'Nicaragua',
#  40: 'Cotoneaster_lacteus',
#  41: 'Nat_Wolff',
#  42: 'Bête_Noire_(album)',
#  43: 'Ex_Libris_(band)',
#  44: 'Eubranchus_occidentalis',
#  45: 'The_Ultimate_School_of_Rock_&_Roll',
#  46: 'Betty_Smith',
#  47: 'A_Prize_of_Arms',
#  48: 'The_Devotion_of_Suspect_X',
#  49: 'JJ_Project',
#  50: 'Brent_Liles',
#  51: 'Claudine_Barretto',
#  52: 'Motownphilly',
#  53: 'Cristina_Fernández_de_Kirchner',
#  54: 'Neil_Sanderson',
#  55: 'Datasoft',
#  56: 'Dark_Waters_(1944_film)',
#  57: 'Kerrie_Manley',
#  58: 'The_Hold_Steady',
#  59: 'Comforter_(song)',
#  60: 'Castle_Keep',
#  61: 'Countdown_to_Extinction',
#  62: 'David_W._Anderson',
#  63: 'Littleton,_Massachusetts',
#  64: 'Littleborough,_Greater_Manchester',
#  65: 'Ellen_Hamlin',
#  66: 'Every_Time_Two_Fools_Collide_(song)',
#  67: 'Frédéric_Henri_Walther',
#  68: 'Connor_Jennings',
#  69: 'Andrei_Gennadyevich_Sidelnikov',
#  70: 'Horace_B._Carpenter',
#  71: 'Eurydema',
#  72: 'Hermogenes_Esperon',
#  73: 'Viva_Death',
#  74: 'Micromonosporaceae',
#  75: 'Asheville,_North_Carolina',
#  76: 'Ángel_Luis_Rodríguez',
#  77: 'Mooki_River',
#  78: 'Yuriy_Putrash',
#  79: 'Cruzeiro_Esporte_Clube',
#  80: 'Frank_Dehne',
#  81: 'Ralph_Richardson',
#  82: 'Shivmangal_Singh_Suman',
#  83: 'Livewire_(Supergirl)',
#  84: 'The_Rank_Group',
#  85: 'Ljubomir_Stevanović',
#  86: 'Incentive_Software',
#  87: 'Lynda_Carter',
#  88: 'So_Far...',
#  89: 'Monema_(moth)',
#  90: 'Amer_Sports',
#  91: 'Chicago_Rush',
#  92: 'Apidae',
#  93: 'Adam_Walker_(Australian_politician)',
#  94: 'Life_in_Dreaming',
#  95: 'Mitch_Versteeg',
#  96: 'Blessed_Are_the_Sick',
#  97: 'Ken_Kramer',
#  98: 'Stilifer',
#  99: 'Superbeast',
#  100: 'The_Wall_Street_Shuffle',
#  101: 'North_Luffenham',
#  102: 'Dragi_Kanatlarovski',
#  103: 'Gold_Panda',
#  104: 'Facundo_Argüello_(footballer)',
#  105: 'In_the_Heat_of_the_Sun',
#  106: 'Hard_Country_(album)',
#  107: 'Lee_Williams_(actor)',
#  108: 'Havířov',
#  109: 'The_Curse_of_the_Pharaohs_(novel)',
#  110: 'Bâsca_Chiojdului_River',
#  111: 'Bobsleigh_at_the_2006_Winter_Olympics_–_Two-man',
#  112: 'Twins_Affair',
#  113: 'Big_Moves',
#  114: '12_Songs_of_Christmas_(Etta_James_album)',
#  115: 'Comacmaeops_brunnea',
#  116: 'Patton_Oswalt',
#  117: "Not_the_Nine_O'Clock_News",
#  118: '1968_Australian_Grand_Prix',
#  119: 'Channel_V_Philippines',
#  120: 'A_Man_This_Lonely',
#  121: 'Inland_Empire',
#  122: 'BSD_licenses',
#  123: 'Vivimed_Labs',
#  124: 'Pharoah_Sanders',
#  125: 'Tiffany_Stiegler',
#  126: 'Shooting_Star_(Tara_McDonald_song)',
#  127: 'EES_(rapper)',
#  128: 'Bachelor_of_Arts_(film)',
#  129: 'Henry_Forrest_(racehorse_trainer)',
#  130: 'Marcy,_New_York',
#  131: 'Dave_Edmunds',
#  132: 'Navy_blue',
#  133: 'Spain_national_under-21_football_team',
#  134: 'Jack_Taylor_(Arizona_politician)',
#  135: 'The_Firebird_(1934_film)',
#  136: 'Back_to_Sleep_(song)',
#  137: 'Edo_Murtić',
#  138: 'Burnet_companion_moth',
#  139: 'Violeta_Violeta',
#  140: 'Triangle_(Perfume_album)',
#  141: 'Mr._Wendal',
#  142: 'Poecilanthe',
#  143: 'Pirmurod_Burkhanov',
#  144: 'Convolvulaceae',
#  145: 'Rodrigo_Thiesen',
#  146: 'Mławianka_Mława',
#  147: 'Trigonopterus',
#  148: 'Golmaal:_Fun_Unlimited',
#  149: 'Robbie_McIntosh_(drummer)',
#  150: 'Victor_Bruck',
#  151: 'Iisa_Pa_Lamang',
#  152: 'Charles_Craft',
#  153: 'Anthony_McAuliffe',
#  154: 'Vucherens',
#  155: 'Queco_Piña',
#  156: 'List_of_opera_directors',
#  157: 'Kévin_Constant',
#  158: 'Tetraibidion',
#  159: 'Rocky',
#  160: 'Pixelh8',
#  161: 'Padam_Padam..._The_Sound_of_His_and_Her_Heartbeats',
#  162: 'Quin,_County_Clare',
#  163: 'Second_Link_Expressway',
#  164: 'Zee_Studio',
#  165: 'Ashley_Tisdale',
#  166: 'Oleksandr_Musiyenko',
#  167: '30_Years_of_Bananarama',
#  168: 'GM_A_platform',
#  169: 'Vitali_Nidbaykin',
#  170: 'Gmina_Wieleń',
#  171: 'Ministry_of_Human_Resource_Development',
#  172: 'Cambuslang',
#  173: 'Free_Will_(album)',
#  174: 'English-speaking_Quebecer',
#  175: 'The_Night_of_the_Generals',
#  176: 'Marshalltown,_Iowa',
#  177: 'Noah_Bernardo',
#  178: 'Hot_Chelle_Rae',
#  179: 'Little_Shocks',
#  180: 'Khvormiz_Rural_District',
#  181: "They_Don't_Care_About_Us",
#  182: 'Eric_Fellner',
#  183: 'Arman_Ramezani',
#  184: 'Henry_I_of_Cyprus',
#  185: '1980_Argentine_Grand_Prix',
#  186: 'Rușchița_River',
#  187: 'T._Raghavaiah',
#  188: 'Acroceridae',
#  189: 'Husky_Be_My_Guide',
#  190: 'Assicurazioni_Generali',
#  191: 'The_God_King',
#  192: 'Gold_Lion',
#  193: 'Rachid_Farssi',
#  194: 'Preggers',
#  195: 'Chris_Hughes_(record_producer)',
#  196: 'Disney_XD_(Southeast_Asia)',
#  197: 'Mimoropica',
#  198: 'Jerome_Dillon',
#  199: 'Gangai_Amaran',
#  200: 'Aghvan_Papikyan',
#  201: 'Kochi',
#  202: 'Adrián_Caetano',
#  203: 'I_Love_Money_(season_4)',
#  204: 'José_Antonio_Ardanza',
#  205: 'Loyola_University_New_Orleans_College_of_Law',
#  206: 'Brad_Brown',
#  207: 'Saphir_Taïder',
#  208: 'Oula_Jääskeläinen',
#  209: 'Gerbstedt',
#  210: 'Rhynchosia_viscosa',
#  211: 'Woodland,_Washington',
#  212: 'Boba_Fett:_Maze_of_Deception',
#  213: 'Compass_Point_Studios',
#  214: 'Nicole_Couch',
#  215: 'Rothschildia',
#  216: 'Richard_Davies_(actor)',
#  217: 'Clive_Cussler',
#  218: 'White_Water,_White_Bloom',
#  219: 'István_Bittó',
#  220: 'The_Best_of_George_Harrison',
#  221: 'Tokyo_Gas',
#  222: 'The_Battle_of_Midway_(film)',
#  223: 'Armageddon_(1998_film)',
#  224: 'The_Legacy_(song)',
#  225: 'Penghu',
#  226: 'William_Hall_(governor)',
#  227: 'Felimare_californiensis',
#  228: 'Gabriel_o_Pensador',
#  229: 'Phlogophora',
#  230: 'King_of_New_York_(song)',
#  231: 'Paul_May',
#  232: 'University_of_Winnipeg',
#  233: 'Clifton_Fadiman',
#  234: 'Brandýs_nad_Labem-Stará_Boleslav',
#  235: 'Mass_spectrometry',
#  236: 'Bay_Street',
#  237: '1986_Canadian_Grand_Prix',
#  238: 'Bo_Bruce',
#  239: 'Lachen,_Switzerland',
#  240: 'Adiantum',
#  241: 'Urban_agglomeration_of_Longueuil',
#  242: 'Arab_Canadians',
#  243: 'St._Helena_AVA',
#  244: 'Jennifer_Jayne',
#  245: 'Gustavo_Canales',
#  246: 'Wah_Wah',
#  247: 'Men_Are_Such_Fools_(1932_film)',
#  248: 'Power_Station_(Taiwanese_band)',
#  249: 'Sunrise_Nippon/Horizon',
#  250: 'Paul_Neville_(musician)',
#  251: 'Lydia_Shum',
#  252: 'Cold_is_the_Grave',
#  253: 'Kohei_Morita',
#  254: 'Brass_Monkey_(song)',
#  255: 'Audi_S5',
#  256: 'Chester_County,_Pennsylvania',
#  257: 'Cefn_Druids_A.F.C.',
#  258: 'Giorgi_Shashiashvili',
#  259: "It's_the_Things_You_Do",
#  260: 'Poshtkuh_Rural_District_(Bushehr_Province)',
#  261: 'The_American_Embassy',
#  262: 'Somewhere_in_Time_(Iron_Maiden_album)',
#  263: 'Montenegrin_Basketball_League',
#  264: 'Mikhail_Lomonosov',
#  265: 'Abdur_Rashid_Kardar',
#  266: 'Vangueriopsis_longiflora',
#  267: 'Strange_Weirdos',
#  268: 'Vicente_Engonga',
#  269: 'Canaan,_New_York',
#  270: 'Maxime_Bôcher',
#  271: 'Einfochips',
#  272: "The_Invisible_Man's_Revenge",
#  273: 'New_York_weevil',
#  274: 'Zana_Nimani',
#  275: 'Colin_Stephen_Quality_Handicap',
#  276: 'VfL_Wolfsburg',
#  277: 'Polynesian_(horse)',
#  278: 'California_State_Assembly',
#  279: 'Grigory_Kaminsky',
#  280: 'H.I.T_(TV_series)',
#  281: 'Sucré_(band)',
#  282: 'Noel_Murless',
#  283: 'Hazel_Court',
#  284: 'Sergei_Kolosov',
#  285: 'Vladimir_Karalić',
#  286: 'Arman_Ghasemi',
#  287: 'Everybody_Knows_(Dixie_Chicks_song)',
#  288: 'Oka_River',
#  289: 'Magic_Stick',
#  290: 'Emmanuel_Joseph_Sieyès',
#  291: 'Leandro_Lessa_Azevedo',
#  292: "Maui_'alauahio",
#  293: 'Diego_Gómez_(Colombian_footballer)',
#  294: 'Thriller_(genre)',
#  295: 'Manhounds_of_Antares',
#  296: 'Billy_Steinberg',
#  297: 'Solon_Bixler',
#  298: 'Landry_Bonnefoi',
#  299: 'Paul_Tsongas',
#  300: 'Ipecac_Recordings',
#  301: 'Brenneke',
#  302: 'RAF_Second_Tactical_Air_Force',
#  303: 'The_Skiffle_Sessions_–_Live_in_Belfast_1998',
#  304: 'Romantic_Warriors_III:_Canterbury_Tales',
#  305: 'The_Rhodes_Not_Taken',
#  306: 'The_Catalogue',
#  307: "Can't_Let_Her_Get_Away",
#  308: 'The_Last_Panthers',
#  309: 'Sad_Eyes_(Bruce_Springsteen_song)',
#  310: "Clive_Barker's_Jericho",
#  311: 'ACF_Fiorentina',
#  312: 'Elf_(band)',
#  313: 'Kevin_Baron_(footballer)',
#  314: 'Radwimps_3:_Mujintō_ni_Motte_Ikiwasureta_Ichimai',
#  315: 'Minutemen_(film)',
#  316: 'Daedalus_(band)',
#  317: 'Nattukottai_Nagarathar',
#  318: 'Microblepsis',
#  319: 'RCA_Records',
#  320: 'Richard_Lewis_(comedian)',
#  321: 'Simon_Gregorčič',
#  322: 'Livistona',
#  323: 'Port_of_Spain',
#  324: 'Aminatou_Haidar',
#  325: 'The_Godfather_Part_II',
#  326: 'No_Reason',
#  327: 'John_Washington',
#  328: "Sing_Along_With_Skankin'_Pickle",
#  329: 'Robert_Gordon_(musician)',
#  330: 'Kaspars_Daugaviņš',
#  331: 'Diagnosis:_Unknown',
#  332: 'Die_Apokalyptischen_Reiter',
#  333: 'Bang_Masters',
#  334: 'Mambo_(music)',
#  335: 'Dolce_Vita_(TVB)',
#  336: 'Sead_Ramović',
#  337: 'Paul_Winterhart',
#  338: 'Mickey_Finn_(drummer)',
#  339: 'Henry_Czerny',
#  340: 'Buccinidae',
#  341: 'Ednaswap',
#  342: '1984_German_Grand_Prix',
#  343: 'Jon_Bruning',
#  344: 'Cape_Breton_University',
#  345: 'ʻAkohekohe',
#  346: 'Pierikos_F.C.',
#  347: 'Mbiyu_Koinange',
#  348: 'Gunnar_Guillermo_Nielsen',
#  349: 'Nani',
#  350: 'Biłgoraj_County',
#  351: 'Lac-Beauport,_Quebec',
#  352: 'Nat_Geo_Wild',
#  353: 'Attera_Totus_Sanctus',
#  354: 'KBRE',
#  355: 'Undeniable_(AZ_album)',
#  356: 'The_Other_Side_(1931_film)',
#  357: 'George_Shilling',
#  358: 'Ashton_Nyte',
#  359: 'The_Burning_Train',
#  360: 'Michal_Drahno',
#  361: 'Lancaster_City_F.C.',
#  362: 'O._P._Jindal_Global_University',
#  363: 'You_Are_the_Apple_of_My_Eye',
#  364: 'Elementary_(TV_series)',
#  365: 'Mayen',
#  366: 'Delta_Force:_Black_Hawk_Down',
#  367: 'The_Cult_(TV_series)',
#  368: 'Florence_Ballard',
#  369: 'Shigeru_Joshima',
#  370: 'Montgomery_Clift',
#  371: 'Chris_Armas',
#  372: 'Voices_of_Babylon',
#  373: 'AES_Corporation',
#  374: 'Junior_Parker',
#  375: 'Stewart_Steven',
#  376: 'Wobble_(song)',
#  377: 'George_Orwell',
#  378: 'Band_of_Joy_(album)',
#  379: "Rock_'n'_Roll_Animal",
#  380: 'Battle_of_Mukden',
#  381: 'Dick_Jones_(actor)',
#  382: 'Automobile_layout',
#  383: 'Osman_Sınav',
#  384: 'Doctor_Fink',
#  385: 'Joe_Plummer',
#  386: 'We_Danced',
#  387: 'Sterculioideae',
#  388: 'Oldenzaal',
#  389: 'Tranz_Metro',
#  390: 'The_Singles_Collection_Volume_1',
#  391: 'Santo_Pecado',
#  392: 'HC_Lev_Praha',
#  393: 'Goodwood_Racecourse',
#  394: 'Lactobacillaceae',
#  395: 'Cross_Plains,_Texas',
#  396: 'Aretha_Franklin',
#  397: 'Johan_Olsson_(skier)',
#  398: 'Luciano_Foschi',
#  399: 'Senecio_maranguensis',
#  400: 'Johnny_Bush',
#  401: 'Flava_(song)',
#  402: 'Carrie_(1976_film)',
#  403: 'Genesis_(Elvin_Jones_album)',
#  404: 'WGCI-FM',
#  405: 'Pride_and_Glory_(film)',
#  406: 'Miroslav_Kraljević',
#  407: 'Ryan_McGivern',
#  408: "King's_Royal_Rifle_Corps",
#  409: 'Nihalchand',
#  410: 'Charles_Semblat',
#  411: 'Camelot_(TV_series)',
#  412: 'Frank_Quitely',
#  413: 'Sheriff',
#  414: 'Jab_Tak_Hai_Jaan_(soundtrack)',
#  415: 'C._S._Lee',
#  416: 'Even_If_It_Kills_Me',
#  417: 'Social_Register_(film)',
#  418: 'Andrew_Kosove',
#  419: 'Witness_(UK_band)',
#  420: 'Steve_Crane',
#  421: 'Maurizio_Lucidi',
#  422: 'U.D._Oliveirense',
#  423: 'The_Taste_of_Others',
#  424: 'Haya_van_Someren',
#  425: 'Tito_and_Me',
#  426: 'José_Batista',
#  427: 'Raef_al_Hasan_Rafa',
#  428: 'Dragiša_Žunić',
#  429: 'Raj_Kumar_Verka',
#  430: 'Dong_Biwu',
#  431: 'Henry_Isaac',
#  432: 'Baliuag,_Bulacan',
#  433: 'Sneak_Previews',
#  434: 'Robert_White_(ambassador)',
#  435: 'Kuhdasht-e_Sharqi_Rural_District',
#  436: 'Paperhouse_(film)',
#  437: 'In_Caliente',
#  438: 'Shinca_Entertainment',
#  439: 'Inopsis',
#  440: 'Actinella',
#  441: 'José_Eduardo_Franco',
#  442: 'What_Kind_of_Fool_(Heard_All_That_Before)',
#  443: 'Johan_Dahlin',
#  444: 'Fado',
#  445: 'Carrian_Group',
#  446: 'Marcin_Mięciel',
#  447: 'Division_of_Indi',
#  448: 'Mass_media',
#  449: 'Leinster_Rugby',
#  450: 'I_Feel_Like_Loving_You_Again',
#  451: 'Ben_E._King',
#  452: 'Michael_Kitchen',
#  453: 'Anton_Babchuk',
#  454: "St._John's_University_(New_York_City)",
#  455: 'Rabat_Ajax_F.C.',
#  456: 'Steffisburg',
#  457: 'Time_Travelling_Blues',
#  458: 'Strong_Enough_to_Bend',
#  459: 'The_Convict_from_Istanbul',
#  460: 'Greater_Poland_Voivodeship',
#  461: 'Dil_Pardesi_Ho_Gaya',
#  462: 'Anthology',
#  463: "Andriy_Donets'",
#  464: 'Redneck_Rampage',
#  465: 'FC_Buran_Voronezh',
#  466: 'Memoria_(song)',
#  467: 'Shawn_Moore',
#  468: 'I_Do_(Lost)',
#  469: 'Veolia',
#  470: 'Oculus_VR',
#  471: 'Love_Is_Like_a_Butterfly_(song)',
#  472: 'Villiers,_Switzerland',
#  473: 'P.O.W_(Bullet_for_My_Valentine_song)',
#  474: 'Zygophyllum',
#  475: 'Michael_Spiller',
#  476: "Love's_Unending_Legacy",
#  477: 'Indian_Creek_(Boise_River)',
#  478: 'Pacific_Coast_Rambler',
#  479: 'Melvin_Platje',
#  480: 'Stenosphenus',
#  481: 'D-beat',
#  482: 'Philip_H._Lathrop',
#  483: 'Camelini',
#  484: 'Rosie_Huntington-Whiteley',
#  485: 'Walter_Hollaender',
#  486: 'Martin_Stoll',
#  487: 'The_Revenant_Choir',
#  488: 'Sessa,_Ticino',
#  489: 'Dreaming_My_Dreams_(Waylon_Jennings_album)',
#  490: 'Tokaikko_Junjō',
#  491: 'Stefano_Pellegrini_(footballer_born_1967)',
#  492: 'Star_Wars:_Battlefront_(2004_video_game)',
#  493: '2009_in_Strikeforce',
#  494: 'Thai_Airways',
#  495: 'Grêmio_Foot-Ball_Porto_Alegrense',
#  496: 'He_Long',
#  497: 'Trudy_Grant',
#  498: 'Tamar_&_Vince',
#  499: 'JLaine',
#  500: 'Robert_Delbourgo',
#  501: 'Crushed_by_the_Wheels_of_Industry',
#  502: 'VMO-2',
#  503: 'White_Lies_(band)',
#  504: 'Just_Whitney',
#  505: 'Frederick_Steele',
#  506: 'Sierra_Leone',
#  507: 'Anthony_Ian_Berkeley',
#  508: 'Reinhold_Knacke',
#  509: 'Ali_Nuhu',
#  510: 'Alexander_De_Croo',
#  511: 'Floral_Green',
#  512: 'Edem_(rapper)',
#  513: 'A._Harry_Moore',
#  514: 'Jerry_Fodor',
#  515: '19th_Virginia_Infantry',
#  516: 'Aron_da_Silva',
#  517: 'Ulrich_Körner',
#  518: 'Vitellariopsis',
#  519: 'Doncamatic',
#  520: 'Big_Big_Deal',
#  521: 'J._D._DeBlieux',
#  522: 'Kate_Jackson_(singer)',
#  523: 'Félix_Brillant',
#  524: 'Brother_Bear_(soundtrack)',
#  525: 'Page_Eight',
#  526: 'Inkdeath',
#  527: 'Itabuna_Esporte_Clube',
#  528: 'Tone_Mason',
#  529: '20th_Division_(German_Empire)',
#  530: 'Out_of_Sight',
#  531: 'Marcus_Browning',
#  532: 'WWE_SmackDown_vs._Raw_2011',
#  533: 'Loleatta_Holloway',
#  534: 'Ferenbalm',
#  535: '1985_German_Grand_Prix',
#  536: 'If_I_Needed_You',
#  537: 'Ost_Autobahn',
#  538: 'Independiente_del_Valle',
#  539: 'Reisangmei_Vashum',
#  540: 'Frankie_Chan',
#  541: 'Claude_de_Givray',
#  542: 'Josh_Thompson_(footballer)',
#  543: 'Stu_Phillips_(composer)',
#  544: 'Selena_(album)',
#  545: 'Nancy_Lee_Bass',
#  546: 'Thomas_Kwok',
#  547: 'Steve_Chiasson',
#  548: 'Harry_Black_(politician)',
#  549: 'Dalbeattie',
#  550: 'The_Mysterious_Castle_in_the_Carpathians',
#  551: 'Rodrigo_Pimpão',
#  552: 'Veneridae',
#  553: 'The_Mating_Call',
#  554: 'New_Tattoo_(song)',
#  555: 'Jamaica_College',
#  556: 'Regimental_Reconnaissance_Company',
#  557: 'Enter_the_Eagles',
#  558: 'Kevin_Finlayson',
#  559: 'Khvaf_County',
#  560: 'Billy_Cobham',
#  561: 'Nitro_Records',
#  562: 'André_Felipe_Ribeiro_de_Souza',
#  563: 'Lars_Eric_Si',
#  564: 'Lovelite',
#  565: 'Foggia',
#  566: 'Shree_Venkatesh_Films',
#  567: 'Shake,_Rattle_&_Roll_IV',
#  568: 'Jaworzno',
#  569: 'Elixir_Studios',
#  570: 'Kavli_Prize',
#  571: 'Ward_County,_Texas',
#  572: 'Sprague_Cleghorn',
#  573: 'Loving_You_(Nina_Girado_song)',
#  574: 'Peyton_Young',
#  575: 'Generation_Iron',
#  576: 'Helmut_Haugk',
#  577: 'West_Point_Cemetery',
#  578: 'Triumph_of_the_Spirit',
#  579: 'Shahid_Nadeem',
#  580: 'Deportivo_Walter_Ferretti',
#  581: "Who's_David",
#  582: 'Gene_Wolfe',
#  583: 'Wrexham_F.C.',
#  584: 'Mange_Tout',
#  585: 'Sphiggurus',
#  586: 'George_Murdock_(actor)',
#  587: 'The_Platinum_Brothers',
#  588: 'O.P.P._(song)',
#  589: 'Krishna_Kumari_(actress)',
#  590: 'Fuel_TV_(Australia)',
#  591: 'Ralph_Edwards_(conservationist)',
#  592: 'Talkdemonic',
#  593: 'Abt_Sportsline',
#  594: 'Portales,_New_Mexico',
#  595: '¡Three_Amigos!',
#  596: 'Chin_Siu-ho',
#  597: 'Louise_Dresser',
#  598: 'Chris_Lebenzon',
#  599: 'Aitraaz',
#  600: 'Algerian_War',
#  601: 'Summer_Scent',
#  602: 'Tuttlingen',
#  603: 'Between_the_Darkness_and_the_Light',
#  604: 'Benn_Levy',
#  605: 'Chris_Eldridge',
#  606: 'James_Glennon',
#  607: 'The_Crime_of_Monsieur_Lange',
#  608: 'In_My_Heart_(Texas_song)',
#  609: 'Julius_Patrick',
#  610: 'Nicholas_Loftin',
#  611: 'Kissed_by_Fire',
#  612: 'Jarrett_Deuling',
#  613: 'Hakim_Medane',
#  614: 'Basque_nationalism',
#  615: 'Pawleys_Island,_South_Carolina',
#  616: 'Stanley_Ka_Dabba',
#  617: 'The_Who_at_Kilburn:_1977',
#  618: 'Hunter,_Prey',
#  619: 'Fritillaria',
#  620: 'GLC_(rapper)',
#  621: 'Amy_Winehouse_at_the_BBC',
#  622: 'Bosco_Mann',
#  623: 'The_Real_Housewives_of_New_Jersey',
#  624: 'User-generated_content',
#  625: 'Habrona',
#  626: 'Sahasam_Swasaga_Sagipo',
#  627: 'Luca_Tremolada',
#  628: 'Noel_Gallagher',
#  629: 'Dave_Pell',
#  630: 'MTV_Thailand',
#  631: 'Alistair_Edwards',
#  632: 'Erik_Tønne',
#  633: 'All_You_Need_Is_Love',
#  634: 'Karsten_Wettberg',
#  635: 'King_of_the_Gamblers',
#  636: 'Paramount_Television_Service',
#  637: 'Mongo_Wrestling_Alliance',
#  638: 'City_Guys',
#  639: 'Walt_Weiskopf',
#  640: 'Hollie_Cook',
#  641: 'Alma_indomable',
#  642: 'Utzenstorf',
#  643: 'Shiva_Pasupati',
#  644: 'You_and_Me_(Lifehouse_song)',
#  645: 'Hardy,_Arkansas',
#  646: 'Sulfur_(song)',
#  647: 'Sarvggun_Sampanna',
#  648: 'Department_for_Business,_Innovation_and_Skills',
#  649: 'Unit_187',
#  650: 'Taaha_Shah',
#  651: 'FC_Amur-2010_Blagoveshchensk',
#  652: '1961_Danish_Grand_Prix',
#  653: 'Ralph_MacSweyn',
#  654: 'Ron_Carter_(ice_hockey)',
#  655: 'Phil_Barnes',
#  656: 'Peter_I,_Count_of_Urgell',
#  657: 'Symfonia',
#  658: 'EBX_(album)',
#  659: 'Family_Brown',
#  660: 'The_Rugrats_Movie',
#  661: 'Seibu_Haijima_Line',
#  662: 'St._Marxmen',
#  663: 'Shop_TV',
#  664: 'The_Chamber_(film)',
#  665: 'Wyndham_Gittens',
#  666: 'National_Alliance_(Latvia)',
#  667: 'Leptothorax',
#  668: 'Valeri_Smolkov',
#  669: 'Thiago_Gentil',
#  670: 'The_L.A._Complex',
#  671: 'Front_2_Back',
#  672: 'My_Boy_(Buono!_song)',
#  673: 'Zsolt_Nagy_(footballer)',
#  674: 'Vriesea_fenestralis',
#  675: 'Battle_of_Bladensburg',
#  676: 'Swammerdamia',
#  677: 'San_Diego_Gulls',
#  678: '1976_in_music',
#  679: 'RCTV_International',
#  680: 'Bobby_Howe_(footballer,_born_1945)',
#  681: 'Luiz_Oliveira_dos_Santos_Júnior',
#  682: 'Hello,_Goodbye',
#  683: 'Kharar,_SAS_Nagar',
#  684: 'Burlingame,_Kansas',
#  685: '1995–96_Portsmouth_F.C._season',
#  686: 'EP_Daily',
#  687: 'Club_Atlético_Douglas_Haig',
#  688: 'Fair_Grounds_Oaks',
#  689: 'Las_Vegas,_New_Mexico',
#  690: 'Greetings_from_Tucson',
#  691: 'David_Weiss_(musician)',
#  692: 'Bollywood',
#  693: 'Vaudeville',
#  694: 'Adia',
#  695: 'Playground_(Steve_Kuhn_&_Sheila_Jordan_album)',
#  696: 'In_Full_Effect',
#  697: 'Carnival_(1931_film)',
#  698: 'Hargreaves_Lansdown',
#  699: 'C._V._Sridhar',
#  700: 'The_Lucy_Show',
#  701: 'Barclays_Bank_(Kenya)',
#  702: 'Mark_Wilson_(English_footballer)',
#  703: 'Alireza_Samimi',
#  704: 'Just_Perfect',
#  705: 'The_Hard_Way_(1943_film)',
#  706: 'Álex_Aguinaga',
#  707: 'Flying_Down_to_Rio',
#  708: 'Eutaw,_Alabama',
#  709: 'Reg_Abbott',
#  710: 'Final_Exit_(band)',
#  711: 'Blue_Ridge,_Georgia',
#  712: 'Jackie_DeShannon',
#  713: 'Statistics',
#  714: 'Werner_Gust',
#  715: 'Live_Bites',
#  716: 'Vegetable',
#  717: 'University_of_Alabama_School_of_Law',
#  718: 'William_Hanna',
#  719: 'Churchill_College,_Cambridge',
#  720: 'History_of_U.S._Pergolettese_1932',
#  721: 'Purdue_University',
#  722: 'Spencer_Williams',
#  723: 'Terry_Carkner',
#  724: 'Fnac',
#  725: 'Edward_Grange',
#  726: 'TVR_Info',
#  727: 'Roger_Walker_(footballer)',
#  728: 'Edd_Kalehoff',
#  729: 'Enemy_of_My_Enemy',
#  730: 'GRP_Records',
#  731: 'UniBank',
#  732: 'The_Planet_Smashers',
#  733: 'Joe_Walker_(editor)',
#  734: 'Wanted_Man_(Ratt_song)',
#  735: 'Mississippi_College',
#  736: 'Panagiotis_Stamogiannos',
#  737: 'Bleed_Like_Me_(song)',
#  738: 'Center_Stage_(2000_film)',
#  739: 'Try_Whistling_This',
#  740: 'Macrozamia',
#  741: 'Hannibal_Rising_(film)',
#  742: 'John_Gray_(director)',
#  743: 'Ramesh_Chandra_Jha',
#  744: 'Clem_Hawke',
#  745: 'Etiquette_for_Mistresses',
#  746: 'Sunset_People',
#  747: 'Marcin_Truszkowski',
#  748: 'John_Madejski',
#  749: 'Rough_&_Ready',
#  750: 'Marx_Reloaded',
#  751: 'Kadoma,_Zimbabwe',
#  752: 'Roy_Keith_Black',
#  753: 'Ralph_Moor',
#  754: '2013–14_Bundesliga',
#  755: 'Gianluca_De_Angelis_(footballer_born_1981)',
#  756: 'KBS_Cool_FM',
#  757: 'Krishnam_Raju',
#  758: 'Stephen_Moyer',
#  759: 'History_of_Derby_County_F.C._(1967–present)',
#  760: 'Love_in_Motion_(song)',
#  761: 'Costas_Elia',
#  762: 'Wallowa_County,_Oregon',
#  763: "The_Woodwright's_Shop",
#  764: 'Dave_Krusen',
#  765: 'Kodiak_Island_Borough,_Alaska',
#  766: 'Rampla_Juniors',
#  767: 'Fancy_Lady_Without_Money',
#  768: 'Chah_Dadkhoda_Rural_District',
#  769: "Who's_Crying_Now",
#  770: 'Novellara',
#  771: 'Doug_Martsch',
#  772: 'Stevie_Stone',
#  773: 'Openings_(The_Killing)',
#  774: 'Final_Destination_3',
#  775: 'The_Music_Scene_(TV_series)',
#  776: 'Les_Jumo',
#  777: 'Gilbert_Ryle',
#  778: 'Bad_Attitude_(album)',
#  779: 'When_Women_Had_Tails',
#  780: 'Rachel_Stowell',
#  781: 'Linglestown,_Pennsylvania',
#  782: 'Susan_Peters',
#  783: 'Negotiations_and_Love_Songs',
#  784: 'Connie_Willis',
#  785: 'Junkie_XL',
#  786: 'Eram_Rural_District',
#  787: 'Mordellistena_cincta',
#  788: 'Roy_Orbison',
#  789: 'Edmilson_Carlos_Abel',
#  790: 'Alfred_Shout',
#  791: 'Born_This_Way_(song)',
#  792: 'Roses_of_Picardy_(film)',
#  793: 'The_Weather_Girls',
#  794: 'Abryna',
#  795: 'John_Wilkinson_(Franklin_automobile)',
#  796: 'The_Simpsons_Movie:_The_Music',
#  797: 'Herbert_Wilcox',
#  798: 'Louis_Thomas_Villaret_de_Joyeuse',
#  799: 'Auckland_Airport',
#  800: 'Hungry_Ghosts_(album)',
#  801: 'Man_on_the_Moon:_The_End_of_Day',
#  802: 'Michael_Mery',
#  803: 'Edgar_Castillo',
#  804: "Oh_Dad,_Poor_Dad,_Mamma's_Hung_You_in_the_Closet_and_I'm_Feelin'_So_Sad",
#  805: 'Joyce_Aubrey',
#  806: 'Intergalactic_(song)',
#  807: 'Arthur_MacArthur_III',
#  808: 'WJZQ',
#  809: 'Michael_Gaston',
#  810: 'Sir_Benjamin_Collins_Brodie,_2nd_Baronet',
#  811: 'Ezo_(band)',
#  812: 'Viz_Media_Europe',
#  813: 'Gotta_Tell_You_(song)',
#  814: 'Didier_Tholot',
#  815: 'Ghent,_New_York',
#  816: 'Battledragon',
#  817: 'Olga_Levina_(draughts_player)',
#  818: 'Daiwa_House',
#  819: 'The_Game_(Alyssa_Reid_song)',
#  820: 'Deinandra_fasciculata',
#  821: 'We_Are_Not_Alone_(1939_film)',
#  822: 'Ashley_Judd',
#  823: 'Tomáš_Hübschman',
#  824: 'Cristian_Săpunaru',
#  825: 'Milton_Brown',
#  826: 'Silverthorn_(album)',
#  827: 'Osteomeles',
#  828: 'Melphina',
#  829: 'Jag_är_inte_rädd_för_mörkret',
#  830: 'Hold_Your_Fire_(FireHouse_album)',
#  831: 'Ethnomusicology',
#  832: 'Bob_Power',
#  833: 'Denys_Harmash',
#  834: 'Frenemies_(film)',
#  835: 'Words_and_Music_(Paul_Kelly_album)',
#  836: '1993_Hungarian_Grand_Prix',
#  837: 'Laburnum_Grove',
#  838: 'Rodrigo_Leão',
#  839: 'Hold_On_(Good_Charlotte_song)',
#  840: 'Functional_analysis',
#  841: 'Adrian_Caceres',
#  842: 'Ian_Gillan',
#  843: 'Leighton_James',
#  844: 'Army_Black_Knights',
#  845: 'You_Sexy_Thing',
#  846: 'Fabrizio_De_André',
#  847: 'Antonio_Maldonado',
#  848: 'King_Harvest',
#  849: 'Utrecht–Rotterdam_railway',
#  850: 'The_Elephant_Riders',
#  851: 'The_New_Klondike',
#  852: 'Montevideo',
#  853: 'The_Yellow_Tomahawk',
#  854: 'Try_Me_(Jason_Derulo_song)',
#  855: 'Fire_All_Your_Guns_at_Once',
#  856: 'Pseuderanthemum',
#  857: 'Xerinae',
#  858: 'Cameron_A._Morrison',
#  859: 'Scunthorpe_United_F.C.',
#  860: 'Odontoglossum_tenue',
#  861: 'David_Fiuczynski',
#  862: 'Björn_Andersson',
#  863: 'Kovai_Brothers',
#  864: 'CD_Onda',
#  865: 'Machine_Sazi_Tabriz_F.C.',
#  866: 'Emma_Anderson',
#  867: 'New_City_(album)',
#  868: 'Naeim_Saadavi',
#  869: 'Leonardo_Capezzi',
#  870: 'Sinclair_Research',
#  871: 'Drosophilidae',
#  872: 'Hazel',
#  873: 'Alive_(S_Club_song)',
#  874: 'Bob_Mosher',
#  875: 'Siphonarioidea',
#  876: 'Miloš_Dragojević',
#  877: 'West_Dunbartonshire',
#  878: 'Martin_Glover',
#  879: 'Neunforn',
#  880: 'Gustavus_Woodson_Smith',
#  881: 'Utsunomiya',
#  882: 'Mundell_Lowe',
#  883: 'Dafydd_Elis-Thomas',
#  884: 'Football_League_One',
#  885: 'Merl_Saunders',
#  886: 'Nightwish',
#  887: 'Subic,_Zambales',
#  888: 'Bill_Moss,_Jr.',
#  889: 'The_Virtuous_Husband',
#  890: 'Sascha_Lenhart',
#  891: 'Slayers_The_Motion_Picture',
#  892: 'Gary_Owen_(politician)',
#  893: 'MiniD',
#  894: 'Mitsubishi',
#  895: 'Wang_Gang_(footballer)',
#  896: 'Fürth_(district)',
#  897: 'Space_Cowboy_(musician)',
#  898: 'Bernardo_Vieira_de_Souza',
#  899: 'Malkhaz_Asatiani',
#  900: 'Addis_Ababa_University',
#  901: 'Donita_Sparks',
#  902: 'Heather_Cox',
#  903: 'Andrei_Peteleu',
#  904: 'Tim_Fite',
#  905: 'Dave_Treen',
#  906: 'Columbia_County,_Wisconsin',
#  907: '1989_British_Grand_Prix',
#  908: "The_Dennis_O'Keefe_Show",
#  909: '2014_USL_Pro_season',
#  910: 'Alizée',
#  911: 'DJ_A-Tron',
#  912: 'Lord_Infamous',
#  913: 'The_Breakfast_Club',
#  914: 'Zefreh_Rural_District',
#  915: 'Sarmayeh_Bank',
#  916: 'Osage_County,_Kansas',
#  917: 'Mario_Gjurovski',
#  918: 'Peleg_Sprague_(New_Hampshire_politician)',
#  919: 'Candlebox_(album)',
#  920: 'Jarmo_Saastamoinen',
#  921: 'BellSouth',
#  922: 'David_Winters_(choreographer)',
#  923: 'Jacuzzi',
#  924: 'Gustav_von_Escherich',
#  925: 'Basick_Records',
#  926: 'Red_Steagall',
#  927: 'Zrenjanin',
#  928: 'Martisberg',
#  929: 'Álvaro_Silva_(footballer)',
#  930: 'Fairuz',
#  931: 'Time_Will_Crawl',
#  932: 'Powder_(TV_series)',
#  933: 'Push_(Matchbox_Twenty_song)',
#  934: 'Switch_(1991_film)',
#  935: 'Me_and_Mrs._Jones',
#  936: 'Sweet_Revenge_(Ryuichi_Sakamoto_album)',
#  937: 'Obtusipalpis',
#  938: 'Bernie_Worrell',
#  939: 'Alexander_Löhr',
#  940: 'U.S._Route_54',
#  941: 'Berserk!',
#  942: 'Porterhouse_(horse)',
#  943: 'Arachnoides',
#  944: 'Henry_Augustus_Rowland',
#  945: 'Ernst_Börngen',
#  946: 'Liam_Munroe',
#  947: 'Stuart_Barlow',
#  948: 'Horace_Wheddon',
#  949: 'Susan_Boyle',
#  950: 'Ox_(band)',
#  951: 'Karl_von_Czyhlarz',
#  952: 'Ali_Vâsib',
#  953: 'Rod_MacDonald',
#  954: 'Plex_(software)',
#  955: 'Eulogy_Recordings',
#  956: "Year's_Best_SF_13",
#  957: 'Kuruption!',
#  958: 'Manchineel',
#  959: 'River_Thames',
#  960: 'Kangnam_(singer)',
#  961: 'Bomshel',
#  962: "Back_to_the_'50s",
#  963: 'LTJ_Bukem',
#  964: 'KMPX',
#  965: 'Stay_Trippy',
#  966: 'Royal_University_of_Phnom_Penh',
#  967: 'Adrian_Mutu',
#  968: 'Pothyne',
#  969: 'Das_Erste',
#  970: 'Dorothy_Ayer_Gardner_Ford',
#  971: 'Kleyr_Vieira_dos_Santos',
#  972: 'Yevhen_Cheberyachko',
#  973: 'Oh!_Darling',
#  974: 'Nick_Bacon',
#  975: 'Reroute_to_Remain',
#  976: 'Barabbas_(1961_film)',
#  977: 'Frank_Fasi',
#  978: 'Aguila_Saleh_Issa',
#  979: 'Miguel_Albuquerque',
#  980: 'Garry_Peters',
#  981: 'Subramaniam_Siva',
#  982: 'Marilyn_McAdams_Sibley',
#  983: 'Moise_Tshombe',
#  984: 'Rick_ten_Voorde',
#  985: 'The_PJs',
#  986: 'Take_a_Look_(song)',
#  987: 'Concerto_Moon',
#  988: 'The_Camp_Is_Back',
#  989: 'Zenochloris_major',
#  990: 'Aroma_compound',
#  991: 'Jamie_Spaniolo',
#  992: 'DMAX_(TV_channel)',
#  993: 'Antimimistis',
#  994: 'The_Last_Picture_Show',
#  995: 'Murtaza_Rakhimov',
#  996: 'After_Dark_(Andy_Gibb_album)',
#  997: 'Make_Me_Smile_(Come_Up_and_See_Me)',
#  998: "Maids_When_You're_Young_Never_Wed_an_Old_Man",
#  999: 'José_Eduardo_dos_Santos',
#  ...}

# %% [markdown]
# Load the raw test triples

# %%
raw_test_triples = set()
with open(testdata_raw_path, 'rt') as f:
    nfacts = int(f.readline())
    for l in f:
        tkns = l.split(' ')
        h = int(tkns[0])
        t = int(tkns[1])
        r = int(tkns[2])
        raw_test_triples.add((h, t, r))

# %% [markdown]
# Load the test files

# %%
with open(testdata_transe_path_head, 'rb') as fin:
    testdata_transe_head = pkl.load(fin)
with open(testdata_transe_path_tail, 'rb') as fin:
    testdata_transe_tail = pkl.load(fin)
'''
with open(testdata_complex_path_head, 'rb') as fin:
    testdata_complex_head = pkl.load(fin)
with open(testdata_complex_path_tail, 'rb') as fin:
    testdata_complex_tail = pkl.load(fin)
with open(testdata_rotate_path_head, 'rb') as fin:
    testdata_rotate_head = pkl.load(fin)
with open(testdata_rotate_path_tail, 'rb') as fin:
    testdata_rotate_tail = pkl.load(fin)
'''
# Out:
# "\nwith open(testdata_complex_path_head, 'rb') as fin:\n    testdata_complex_head = pkl.load(fin)\nwith open(testdata_complex_path_tail, 'rb') as fin:\n    testdata_complex_tail = pkl.load(fin)\nwith open(testdata_rotate_path_head, 'rb') as fin:\n    testdata_rotate_head = pkl.load(fin)\nwith open(testdata_rotate_path_tail, 'rb') as fin:\n    testdata_rotate_tail = pkl.load(fin)\n"

# %% [markdown]
# Compute all the head and tail queries

# %%
queries_tail = {}
#for name, testset in [("transe", testdata_transe_tail), ("complex", testdata_complex_tail), ("rotate", testdata_rotate_tail)]:
for name, testset in [("transe", testdata_transe_tail)]:
    for t in testset:
        ent = t['ent']
        rel = t['rel']
        if (ent, rel) in queries_tail:
            answers = queries_tail[(ent, rel)]
            if name not in answers:
                answers[name] = t['answers_fil']
        else:
            a = { name : t['answers_fil'] }            
            queries_tail[(ent, rel)] = a

queries_head = {}
# for name, testset in [("transe", testdata_transe_head), ("complex", testdata_complex_head), ("rotate", testdata_rotate_head)]:
for name, testset in [("transe", testdata_transe_head)]:
    for t in testset:
        ent = t['ent']
        rel = t['rel']    
        if (ent, rel) in queries_head:
            answers = queries_head[(ent, rel)]
            if name not in answers:
                answers[name] = t['answers_fil']
        else:
            a = { name : t['answers_fil'] }           
            queries_head[(ent, rel)] = a

# %% [markdown]
# Copy all the queries into a single list. Also, load all the queries previously annotated.

# %%
queries = []
counter = 0
for q, a in queries_head.items():
    queries.append({'id': counter, 'type': 0, 'ent' : q[0], 'rel' : q[1], 'answers' : a})
    counter += 1    
for q, a in queries_tail.items():
    queries.append({'id': counter, 'type': 1, 'ent' : q[0], 'rel' : q[1], 'answers' : a})    
    counter += 1
print("# Queries:", len(queries))
# Out:
# # Queries: 3411

# %% [markdown]
# Global data structures

# %%
out = widgets.Output(layout={'padding': '5px', 'border': '1px solid black'})
array_answers = []
valid_annotations = True
current_query_id = None
processed_queries = {}
n_valid_queries = 0
if os.path.exists(annotations_file):
    print("Loading annotations from file", annotations_file)
    processed_queries = json.load(open(annotations_file, 'rt'))
    new_processed_queries = {}
    for k, v in processed_queries.items():
        new_processed_queries[int(k)] = v
        if v['valid_annotations'] == True:
            n_valid_queries += 1
    processed_queries = new_processed_queries
print("# Processed Queries:", len(processed_queries), " # valid:", n_valid_queries)
# Out:
# # Processed Queries: 0  # valid: 0

# %% [markdown]
# ### Auxiliary functions

# %%
def pick_next_query():
    global current_query_id
    global processed_queries
    if mode == 0:
        if len(processed_queries) < len(queries):            
            n_attempts = 10
            attempt = 0
            found = False
            while attempt < n_attempts:
                idx = random.randint(0, len(queries) - 1)
                if idx not in processed_queries:
                    found = True
                    break
                attempt += 1
            if found:
                current_query_id = idx
            else:
                # Pick the first ID that is not in processed_queries
                for i in range(len(queries)):
                    if i not in processed_queries:
                        found = True
                        current_query_id = i
                        break
                assert(found)
            return True        
        else:
            return None
    else: # mode=1
        # First pick a query not annotated by the current annotator
        for key, query in processed_queries.items():
            annotated_answers = query['annotated_answers']
            found = False
            for annotated_answer in annotated_answers:
                c = annotated_answer['checked']
                for annotation in c:
                    if annotation['annotator'] == annotator:                        
                        found = True
                        break
            if not found:
                # Good, found one
                current_query_id = key
                return True
        return None

# %%
def on_change_checkbox(b):
    owner = b['owner']
    desc = owner.description
    id_answer = int(owner.description[0:desc.find('.')])
    value = b['new']
    found = False
    for ans_annotator in array_answers[id_answer]['checked']:
        if ans_annotator['annotator'] == annotator:
            found = True        
            if value is True:
                ans_annotator['checked'] = True
            else:
                ans_annotator['checked'] = False
            break
    assert(found)

# %%
def dump_on_file():
    # First check if the file exist
    if os.path.exists(annotations_file):
        now = str(datetime.datetime.now())
        old_file = annotations_file + '-' + now
        os.rename(annotations_file, old_file)
    json.dump(processed_queries, open(annotations_file, 'wt'), indent = 6)

# %%
def on_click_button(b):
    global processed_queries
    global current_query_id
    global valid_annotations
    
    out.clear_output()
    # Store the annotation
    query = queries[current_query_id]
    if current_query_id in processed_queries:
        annotators = processed_queries[current_query_id]['annotators']
    else:
        annotators = []
    annotators.append({'annotator' : annotator, 'date' : str(datetime.datetime.now()) })
    processed_queries[current_query_id] = {'query' : query, 'valid_annotations' : valid_annotations, 'annotated_answers' : array_answers, 'annotators' : annotators }
    dump_on_file()
    
    # Move to the next query
    with out:
        ok = pick_next_query()
        if ok is not None:
            query = queries[current_query_id]
            print_query_answers(query['id'], query['type'], query['ent'], query['rel'], query['answers'])

# %%
def on_click_skip_button(b):
    global valid_annotations
    valid_annotations = False
    on_click_button(b)

# %%
def retrieve_wikidata_label(e):
    # Query Wikidata
    try:
        query = 'PREFIX wd: <http://www.wikidata.org/entity/> ' + 'PREFIX wdt: <http://www.wikidata.org/prop/direct/> ' + "SELECT ?x ?xLabel WHERE { ?x wdt:P646 \"" + e + "\"; SERVICE wikibase:label { bd:serviceParam wikibase:language \"[AUTO_LANGUAGE],en\". } }"
        r = requests.get('https://query.wikidata.org/bigdata/namespace/wdq/sparql', params = {'format': 'json', 'query': query})
        if r:
            r = r.json()
            results = r['results']
            bindings = results['bindings']
            # Take the first
            binding = bindings[0]
            value = binding['x']['value']
            lbl = binding['xLabel']['value']
            return lbl, value
    except:
        pass
    return 'None', 'None'

# %%
def print_query_answers(query_id, typ, ent, rel, answers):
    global processed_queries
    global array_answers
    global valid_annotations
    valid_annotations = True
    n_skipped = 0
    n_ok = 0
    n_annotated_answers = 0
    n_tail_queries = 0
    n_head_queries = 0
    for _, q in processed_queries.items():
        if q['valid_annotations']:
            n_ok += 1
            n_annotated_answers += len(q['annotated_answers'])
            if q['query']['type'] == 1:
                n_tail_queries += 1
            else:
                n_head_queries += 1
        else:
            n_skipped += 1
    print("Processed queries: {} Skipped: {} Ok: {} Head: {} Tail: {}".format(len(processed_queries), n_skipped, n_ok, n_head_queries, n_tail_queries))
    print("Annnotated answers: {}\n".format(n_annotated_answers))
    typ_str = 'HEAD'
    if typ == 1:
        typ_str = 'TAIL'
    display(Markdown("***Query #{} Type {}***".format(query_id, typ_str)))
    if db_name == 'fb15k237':
        lbl, link_wikidata = retrieve_wikidata_label(ent_labels[ent])
        ent_str = '[' + lbl + ' ' + link_wikidata + ' (' + ent_labels[ent] + ')]'   
    else:
        lbl, link_wikidata = (ent_labels[ent], "")
        ent_str = lbl
    if typ == 0:
        print("?", rel_labels[rel], ent_str)
    else:
        print(ent_str, rel_labels[rel], "?")
    
    previous_annotations = None
    array_answers = []
    if mode == 1 and query_id in processed_queries:
        print("\nThis query was previously annotated by" + str(processed_queries[query_id]['annotators']))
        previous_annotations = processed_queries[query_id]['annotated_answers']
        array_answers = copy.deepcopy(previous_annotations)

    lbl_google = urllib.parse.urlencode({"q" : lbl})
    google_link = "https://www.google.com/search?hl=en&" + lbl_google
    display(Markdown("***Search on Google:*** {}".format(google_link)))
    print("\nAnswers (striked answers are the ones that are in the testset):")    
    for method, answers_method in answers.items():
        for i, answer in enumerate(answers_method):
            a = answer['entity_id']
            # Should I add it?
            found = False
            for j, array_answer in enumerate(array_answers):
                if array_answer['entity_id'] == a:
                    found = True
                    # add the method if not already there
                    method_found = False                    
                    for m in array_answer['methods']:
                        if m == method:
                            method_found = True
                            break
                    if not method_found:
                        array_answer['methods'].append(method)
                    # Add an entry with the current annotator if it does not exist
                    annotator_found = False
                    for c in array_answer['checked']:
                        if c['annotator'] == annotator:
                            annotator_found = True
                            break
                    if not annotator_found and array_answer['enabled']:
                        array_answer['checked'].append({'annotator' : annotator, 'checked' : False })
                    break                    
            if not found:              
                # Is the answer known to be true?
                found = False
                if typ == 0 and (a, ent, rel) in raw_test_triples:
                    found = True
                if typ == 1 and (ent, a, rel) in raw_test_triples:
                    found = True
                if found:
                    array_answers.append({'entity_id' : a, 'checked' : [{'annotator' : 'Testset', 'checked' : True }], 'methods': [method], 'enabled' : False})
                else:
                    # If mode==1, I'm hiding the previous annotations so that two different annotators may annotate with different values
                    array_answers.append({'entity_id' : a, 'checked' : [{'annotator' : annotator, 'checked' : False }], 'methods': [method], 'enabled' : True})
                        
    for i, a in enumerate(array_answers):
        if db_name == 'fb15k237':
            sleep(1) # Some sleeping is necessary for wikidata            
            lbl, link_wikidata = retrieve_wikidata_label(ent_labels[a['entity_id']])
        else:
            lbl, link_wikidata = (ent_labels[a['entity_id']],'')
        a_str = lbl
        desc = "{}. {} ({}) methods={}".format(i, a_str, a['entity_id'], a['methods'])
        if a['enabled'] == False:
            assert(a['checked'][0]['annotator'] == 'Testset')
            assert(a['checked'][0]['checked'] == True)
            box = widgets.Checkbox(True, id=i, description="<strike>" + desc + "</strike>", layout=Layout(width='2000px', height='20px'), indent=False, disabled=True)
        else:
            box = widgets.Checkbox(False, id=i, description=desc, layout=Layout(width='2000px', height='20px'), indent=False)
        box.observe(on_change_checkbox, names="value")
        display(box)
        if a['enabled'] == True:
            lbl_google = urllib.parse.urlencode({"q" : lbl})
            google_link = "https://www.google.com/search?hl=en&" + lbl_google
            lbl_wikipedia = urllib.parse.urlencode({"search" : lbl})
            wikipedia_link = "https://en.wikipedia.org/w/index.php?" + lbl_wikipedia
            display(Markdown("&ensp;&ensp;&ensp;{} {}".format(google_link, wikipedia_link)))

    print("\n")
    display(Markdown("***Known answers from the testset:***"))
    known_answers = []
    for triple in raw_test_triples:
        if triple[2] == rel:
            if typ == 0 and triple[1] == ent:
                known_answers.append(triple[0])
            if typ == 1 and triple[0] == ent:
                known_answers.append(triple[1])
    assert(len(known_answers) > 0)
    for known_answer in known_answers:
        lbl, link_wikidata = (ent_labels[known_answer],'')
        a_str = lbl
        desc = "{} ({})".format(a_str, known_answer)
        print(desc)

# %% [markdown]
# ### Start the annotation process

# %%
out.clear_output()
ok = pick_next_query()
with out:    
    if ok is not None:
        query = queries[current_query_id]
        print_query_answers(query['id'], query['type'], query['ent'], query['rel'], query['answers'])
b = widgets.Button(description='Submit', style=ButtonStyle(font_weight='bf'))
b.on_click(on_click_button)
b_skip = widgets.Button(description='Skip', style=ButtonStyle(font_weight='bf'))
b_skip.on_click(on_click_skip_button)
display(out)
display(b)
display(b_skip)
# Out:
# Output(layout=Layout(border='1px solid black', padding='5px'))
# Button(description='Submit', style=ButtonStyle(font_weight='bf'))
# Button(description='Skip', style=ButtonStyle(font_weight='bf'))
